# %% [markdown]
# **Intro:**
#
# This figure displays the number of fire events by Pittsburgh neighborhood. I'm going to identify Pittsburgh's best neighborhood using this data. I think the communities within pittsburgh that experience the least amount of fire can be deemed among the best.

# %% [markdown]
# **My code snippets along with explainations:**

# %% [markdown]
# I read the file containing all of the fire data, including neighborhoods, the number of fire reports, and coordinates, after first importing Pandas.

# %%
import pandas as pd

# Read the CSV file
fire = pd.read_csv("fire-Incidents.csv")

# %% [markdown]
# following I use '.value_counts()' to count the number of times a neighborhood appears in the file.

# %%
# Group the data by neighborhood and count the number of fires in each neighborhood
neighborhood_counts = fire['neighborhood'].value_counts()

# %% [markdown]
# Next, I use '.tail()' to find the bottom twenty results of the neighborhoods with the least amount of fires within the file.

# %%
# Get the bottom 20 neighborhoods with the least fires 
bottom_neighborhoods = neighborhood_counts.tail(20)

# %% [markdown]
# After that, I use a bar plot to visually represent the data that I have gathered.

# %%
# Create a bar plot to visualize the neighborhoods with the least fires
bottom_neighborhoods.plot(kind='bar')

# %% [markdown]
# **Conclusion:**

# %% [markdown]
# I chose to examine data that showed how frequently fires occur in different neighborhoods. The data includes different types of fire such as house fires as well as shrub fires because the datasets included a lot of information and provided a lot of useful data. I created a graph showing the bottom 20 neighborhoods with the lowest fire incidence after extracting the data from the file and calculating the total number of fires in each neighborhood. My logic is that there should be the fewest fire incidents in the best neighborhood. Higher fire statistics make me believe that a neighborhood is less safe and, therefore, not deserving of the title of best neighborhood. This is because a higher fire risk can result in higher financial risk at the cost of ones personal domicile and increased stress related to the possibility of a fire occurring close to or inside one's own home. Based on data related to fire incidents, it can be assumed that Mount Oliver Borough is the best neighborhood.
